# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260804/blob/main/tibame20260813.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# *
# **
# ***
# ****
i = 0
while i < 5:
    print("o" * (i + 1))
    i = i + 1

# %%
# ****
#  ***
#   **
#    *
# 空白建: 0 1 2 3
# *: 4 3 2 1
# i: 0 1 2 3
symbol1, symbol2 = " ", "o"
layer = 4
i = 0
while i < layer:
    count1 = i
    count2 = layer - i
    line = symbol1 * count1 + symbol2 * count2
    print(line)
    i = i + 1
# Out:
# oooo
#  ooo
#   oo
#    o

# %%
# ooooooo
#  ooooo
#   ooo
#    o
# 空白建: 0 1 2 3
# o: 7 5 3 1
# i: 0 1 2 3
# -2*i: 0 -2 -4 -6

# layer 第一層
# 4 7
# 5 9
# 6 11
# layer * 2 -> 8 10 12

layer = 5
s1, s2, s3 = " ", "o", " "
i = 0
while i < layer:
    c1 = i
    c2 = (2 * layer - 1) - 2 * i
    c3 = i
    line = s1 * c1 + s2 * c2 + s3 * c3
    print(line)
    i = i + 1
# Out:
# ooooooooo
#  ooooooo
#   ooooo
#    ooo
#     o

# %%
# !開始的不是python程式, 而是終端機命令
# !pip3 install ColabTurtle

# %%
from ColabTurtle.Turtle import *
initializeTurtle(initial_speed=4, initial_window_size=(800,500))

forward(100)
left(90)
forward(200)
right(90)
# goto: 指定一個座標直接走過去
# 座標系統以左上角當(0, 0) 橫x 往右增加 直y 往下增加
goto(400, 500)
# 紀錄位置. 以後直接走到這
x, y = pos()
goto(0, 0)
goto(800, 100)
goto(x, y)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="200.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="150.0" x2="400" y2="500" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400" y1="500" x2="0" y2="0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="0" y1="0" x2="800" y2="100" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="800" y1="100" x2="400" y2="500" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400,500) translate(382, 482)">
# ...

# %%
# 我要你畫出正n邊形
from ColabTurtle.Turtle import *
initializeTurtle(initial_speed=10, initial_window_size=(800,500))

n = 100
angle = (n - 2) * 180 / n
# 我隨便縮的
length = 400 / n
print("邊長是:", length)

i = 0
while i < n:
    forward(length)
    right(180-angle)
    i = i + 1
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %% [markdown]
# - 多行註解/反註解: ctrl + /

# %%
# 我們想畫出sin的圖形
# 我們的 現實坐標系(往上增加) -> 程式座標(往下增加的)
# 所以你原本算出來的y -> 加負號 -y
# 我們想把它移到中間: 算出來是0的時候 + 250(500/2)

# x軸: 把它當成角度(x=180->sin180度)

# y不做一個放大, 你的值就是 -1 1->你根本看不到 sin 250*sin
import math
from ColabTurtle.Turtle import *
initializeTurtle(initial_speed=2, initial_window_size=(800,500))

# 調整初始位置
penup()
goto(0, 250)
pendown()

# x: angle
angle = 90
radian = math.radians(angle)
y = 250 * math.sin(radian)
y_cor = -1 * y + 250
goto(angle, y_cor)

angle = 180
radian = math.radians(angle)
y =  250 * math.sin(radian)
y_cor = -1 * y + 250
goto(angle, y_cor)

angle = 270
radian = math.radians(angle)
y =  250 * math.sin(radian)
y_cor = -1 * y + 250
goto(angle, y_cor)

angle = 360
radian = math.radians(angle)
y =  250 * math.sin(radian)
y_cor = -1 * y + 250
goto(angle, y_cor)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="0" y1="250" x2="90" y2="0.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="90" y1="0.0" x2="180" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="180" y1="250.0" x2="270" y2="500.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="270" y1="500.0" x2="360" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,360,250.0) translate(342, 232.0)">
# ...

# %%
# 把0-800分成n等分: 100分 0 8度 16度 24度 .... 做100次
import math
from ColabTurtle.Turtle import *
initializeTurtle(initial_speed=2, initial_window_size=(800,500))

# 調整初始位置
penup()
goto(0, 250)
pendown()

# x: angle
angle = 90
radian = math.radians(angle)
y = 250 * math.sin(radian)
y_cor = -1 * y + 250
goto(angle, y_cor)

angle = 180
radian = math.radians(angle)
y =  250 * math.sin(radian)
y_cor = -1 * y + 250
goto(angle, y_cor)

angle = 270
radian = math.radians(angle)
y =  250 * math.sin(radian)
y_cor = -1 * y + 250
goto(angle, y_cor)

angle = 360
radian = math.radians(angle)
y =  250 * math.sin(radian)
y_cor = -1 * y + 250
goto(angle, y_cor)
