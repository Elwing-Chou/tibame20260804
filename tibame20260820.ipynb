# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260804/blob/main/tibame20260820.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# WIN: -headers "Origin: https://ani.gamer.com.tw" -i "" anime.mp4
#
# MAC: -headers 'Origin: https://ani.gamer.com.tw' -i '' anime.mp4
#
# cd xxx 可執行的程式 參數
#
# 位置參數(放最後面, 一定會帶入的) 告訴她參數拿來幹嗎 a. 短參數: -V -短參數名 值 b. 長參數: --version --長參數名 值

# %% [markdown]
# - 編碼
#     - 我 -> 0101001(編碼)
#     - 0100100 -> 我(解碼)
#     - 亂碼: 編碼=/=解碼
#     - 以前: 有很多套編碼 -> 現在: 一套編碼 Unicode(萬國碼) utf-8
#     - windows預設編碼: ANSI(繁體中文: BIG5 簡體: GBK)
#     - 不管讀檔寫檔, 請你指定萬國碼

# %%
f = open("a.txt", "w", encoding="utf-8")
# 以前的(function): write(f, "abcde")
# 專屬某種型態的功能(method): f.write("abcde")
f.write("abcde")
# \字: \n \t \b
f.write("\nghi")
# 以前: close(f)
# 專屬功能: f.close()
f.close()

# %%
f = open("a.txt", "r", encoding="utf-8")
# content = read(f)
content = f.read()
print(content)
f.close()
# Out:
# abcde
# ghi

# %% [markdown]
# - 清單:
#     - [20, 30, 40]
#     - 查詢座號: 清單名[編號]
#     - 編號: 0 1 2
#     - 反向編號: -3 -2 -1

# %%
l = [20, 30, 40]

# !
print(l[0])
print(max(l), min(l), sum(l), len(l))
print(l[len(l)-1])
# !
print(l[-1])

l[0] = 99
print(l)

for n in l:
    print("!", n)

for i in range(len(l)):
    print("!", l[i])
# Out:
# 20
# 40 20 90 3
# 40
# 40
# [99, 30, 40]
# ! 99
# ! 30
# ! 40
# ! 99
# ! 30
# ! 40

# %%
import urllib.request as req

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=38250&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()
print(content)
# Out:
# b'{"data":{"danmu":[{"text":"1","color":"#FFFFFF","size":1,"position":0,"time":0,"sn":39929764,"userid":"andy475713"},{"text":"2024.6.23\\u7c3d","color":"#FFFFFF","size":1,"position":0,"time":0,"sn":40108494,"userid":"tcg19648"},{"text":"\\u7c3d\\ud83c\\udf2d\\ufe0f","color":"#FDE53D","size":1,"position":0,"time":0,"sn":40273436,"userid":"shackle9487"},{"text":"2024\\/7\\/3\\u51ac\\u96ea\\u7c3d","color":"#FDE53D","size":2,"position":0,"time":0,"sn":40292119,"userid":"naiyu0429"},{"text":"\\u70ba\\u4f55\\u4e00\\u76f4\\u6c92\\u6cd5\\u770b","color":"#FFFFFF","size":1,"position":0,"time":0,"sn":42343409,"userid":"gtkl20050"},{"text":"2025\\/8\\/6\\u9996\\u7c3d!!!","color":"#FF0026","size":2,"position":2,"time":0,"sn":46004529,"userid":"robloxaron"},{"text":"2025\\uff0f8\\uff0f24","color":"#FF0026","size":2,"position":2,"time":2,"sn":46251836,"userid":"FeiFei88"},{"text":"20250802","color":"#FFFFFF","size":1,"position":0,"time":4,"sn":45952197,"userid":"efg130"},{"text":"20240821 \\u6211\
# ...
