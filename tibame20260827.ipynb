# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260804/blob/main/tibame20260827.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 前端(local)
#     - 呈現網頁
#         - HTML: 網頁內容
#         - CSS: 網頁排版
#             - !!!! 你要找的區塊通常會用特定排版, 透過排版來篩選到他 !!!!
#         - JavaScript: 網頁動態
#             - 很多時候控制你隱藏網址的觸發
#             - 不重要, 因為99%的時候你根本不care誰送的
#
# - 後端(server)
#     - 收網址(http server跑在某個port去接收)
#     - 處理這個網址(python Flask/Django/fastAPI)
#     - 處理網址: 查資料庫(SQL)
#     - 送回回覆(html/mp3/mp4...)

# %% [markdown]
# - CSS 簡介: 找到我想做排版的區塊, 加上排版
#     - 會特別加上可以被分辨的HTML屬性, 來讓他跟別人不一樣
#     - class="分類1 分類2 分類3..."
#     - id="身分證"
#
# - CSS語法:
#     - 利用html名稱:
#         - a{background-color:red}
#     - 利用class名稱:
#         - .js-thumbnail-img{border-radius:50%}
#     - 利用id:
#         - #id名稱{}

# %%
import urllib.request as req
import bs4 as bs

url = "https://tabelog.com/tw/tokyo/rstLst/sweets/?SrtT=rt"
resp = req.urlopen(url)
content = resp.read()
html = bs.BeautifulSoup(content)
rs = html.find_all("div", {"class":"list-rst__body"})
for r in rs:
    name = r.find("a", {"class":"list-rst__rst-name-target"})
    area_genre = r.find("div", {"class":"list-rst__area-genre"})

    name_text = name.get_text().strip()
    name_href = name["href"]
    area_genre_text = area_genre.get_text().strip()

    print(name_text)
    print(name_href)
    print(area_genre_text)
    print("-" * 30)
# Out:
# Bon.nu
# https://tabelog.com/tw/tokyo/A1304/A130401/13184186/
# 參宮橋車站 356m / 法式料理, 牛排, 蛋糕
# ------------------------------
# Yama
# https://tabelog.com/tw/tokyo/A1316/A131602/13279936/
# 白金台車站 725m / 甜食
# ------------------------------
# Okashiya Ucchi
# https://tabelog.com/tw/tokyo/A1309/A130901/13238644/
# 北參道車站 250m / 蛋糕, 西式甜點
# ------------------------------
# 蒼菓
# https://tabelog.com/tw/tokyo/A1307/A130703/13297330/
# 廣尾車站 702m / 甜食
# ------------------------------
# ESPRIT C. KEI GINZA
# https://tabelog.com/tw/tokyo/A1301/A130101/13296199/
# 銀座車站 330m / 法式料理, 甜食
# ------------------------------
# GELATERIA ACQUOLINA
# https://tabelog.com/tw/tokyo/A1317/A131701/13141364/
# 祐天寺車站 45m / 意式冰淇淋/冰淇淋, 軟冰淇淋
# ------------------------------
# Patisserie Ryoko
# https://tabelog.com/tw/tokyo/A1316/A131603/13137010/
# 高輪台車站 423m / 蛋糕, 泡芙, 西式甜點
# ------------------------------
# a tes souhaits!
# https://tabelog.com/tw/tokyo/A1320/A132001/13005853/
# 西荻窪車站 992m / 蛋糕, 甜食
# ...

# %%
{}
