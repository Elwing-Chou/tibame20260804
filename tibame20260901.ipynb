# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260804/blob/main/tibame20260901.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req
import bs4 as bs

url = "https://tabelog.com/tw/tokyo/rstLst/sweets/?SrtT=rt"
resp = req.urlopen(url)
content = resp.read()
html = bs.BeautifulSoup(content)
rs = html.find_all("div", {"class":"list-rst__body"})
for r in rs:
    # 評價/晚價/午價/例假日
    name = r.find("a", {"class":"list-rst__rst-name-target"})
    area_genre = r.find("div", {"class":"list-rst__area-genre"})
    rating = r.find("span", {"class":"c-rating__val"})
    prices = r.find_all("span", {"class":"c-rating-v3__val"})
    lunch_price = prices[1]
    dinner_price = prices[0]
    holiday = r.find("span", {"class":"list-rst__holiday-text"})

    name_text = name.get_text().strip()
    name_href = name["href"]
    area_genre_text = area_genre.get_text().strip()
    rating_text = rating.get_text().strip()
    lunch_price_text = lunch_price.get_text().strip()
    dinner_price_text = dinner_price.get_text().strip()
    holiday_text = holiday.get_text().strip()

    print(rating_text)
    print(name_text)
    print(name_href)
    print(area_genre_text)
    print(lunch_price_text)
    print(dinner_price_text)
    print(holiday_text)
    print("-" * 30)

# %%
import urllib.request as req
import bs4 as bs

def download_page(page):
    url = f"https://tabelog.com/tw/tokyo/rstLst/sweets/{page}/?SrtT=rt"
    resp = req.urlopen(url)
    content = resp.read()
    html = bs.BeautifulSoup(content)
    rs = html.find_all("div", {"class":"list-rst__body"})
    # !!!
    result = []
    for r in rs:
        # 評價/晚價/午價/例假日
        name = r.find("a", {"class":"list-rst__rst-name-target"})
        area_genre = r.find("div", {"class":"list-rst__area-genre"})
        rating = r.find("span", {"class":"c-rating__val"})
        prices = r.find_all("span", {"class":"c-rating-v3__val"})
        lunch_price = prices[1]
        dinner_price = prices[0]
        holiday = r.find("span", {"class":"list-rst__holiday-text"})

        name_text = name.get_text().strip()
        name_href = name["href"]
        area_genre_text = area_genre.get_text().strip()
        rating_text = rating.get_text().strip()
        lunch_price_text = lunch_price.get_text().strip()
        dinner_price_text = dinner_price.get_text().strip()
        holiday_text = holiday.get_text().strip()
        # !
        data = {
            "rating":rating_text,
            "name":name_text,
            "link":name_href,
            "area_genre":area_genre_text,
            "price_lunch":lunch_price_text,
            "price_dinner":dinner_price_text,
            "holiday":holiday_text,
        }
        result.append(data)
    return result

download_page(2)
# Out:
# [{'rating': '3.85',
#   'name': 'Au Bon Vieux Temps 尾山台店',
#   'link': 'https://tabelog.com/tw/tokyo/A1317/A131715/13181654/',
#   'area_genre': '尾山台車站 368m / 蛋糕, 小菜, 咖啡店',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 1,000 - JPY 1,999',
#   'holiday': '星期二, 星期三'},
#  {'rating': '3.85',
#   'name': 'Ryoura',
#   'link': 'https://tabelog.com/tw/tokyo/A1317/A131707/13188208/',
#   'area_genre': '用賀車站 290m / 蛋糕, 西式甜點',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 3,000 - JPY 3,999',
#   'holiday': '星期二, 星期三'},
#  {'rating': '3.85',
#   'name': 'Minimal 富ヶ谷本店',
#   'link': 'https://tabelog.com/tw/tokyo/A1303/A130301/13175834/',
#   'area_genre': '代代木八幡車站 372m / 巧克力, 蛋糕, 咖啡店',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 1,000 - JPY 1,999',
#   'holiday': '-'},
#  {'rating': '3.85',
#   'name': "L'AUTOMNE 中野店",
#   'link': 'https://tabelog.com/tw/tokyo/A1321/A132101/13118933/',
#   'area_genre': '新江古田車站 39m / 蛋糕, 咖啡店, 麵包',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 1,000 - JPY 1,999',
#   'holiday': '星期一, 星期二'},
#  {'rating': '3.84',
#   'name': 'Curry Spice Gelateria KALPASI',
#   'link': 'https://tabelog.com/tw/tokyo/A1318/A131802/13247887/',
#   'area_genre': '下北澤車站 105m / 咖喱, 意式冰淇淋/冰淇淋, 亞洲料理, 民族料理',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 1,000 - JPY 1,999',
#   'holiday': '星期四'},
#  {'rating': '3.84',
#   'name': 'ASTERISQUE',
#   'link': 'https://tabelog.com/tw/tokyo/A1318/A131811/13140735/',
#   'area_genre': '代代木上原車站 172m / 蛋糕',
#   'price_lunch': '- JPY 999',
#   'price_dinner': '- JPY 999',
#   'holiday': '星期一, 星期二'},
#  {'rating': '3.84',
#   'name': '法國菓子 甜點師 巧克力師 Inamurashōzō',
#   'link': 'https://tabelog.com/tw/tokyo/A1311/A131105/13047298/',
#   'area_genre': '日暮里車站 139m / 蛋糕, 巧克力',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 1,000 - JPY 1,999',
#   'holiday': '星期一, 星期二'},
#  {'rating': '3.84',
#   'name': 'La Maison du Chocolat 丸之內店',
#   'link': 'https://tabelog.com/tw/tokyo/A1301/A130102/13000036/',
#   'area_genre': '有樂町車站 180m / 巧克力, 蛋糕, 咖啡店',
#   'price_lunch': 'JPY 3,000 - JPY 3,999',
#   'price_dinner': '-',
#   'holiday': '-'},
#  {'rating': '3.84',
#   'name': 'TORAYA TOKYO',
#   'link': 'https://tabelog.com/tw/tokyo/A1302/A130201/13147493/',
#   'area_genre': '東京車站 128m / 咖啡店, 日式點心, 刨冰',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': '-',
#   'holiday': '-'},
#  {'rating': '3.84',
#   'name': 'Premarché Gelateria 東京中目黑站前店',
#   'link': 'https://tabelog.com/tw/tokyo/A1317/A131701/13223646/',
#   'area_genre': '中目黑車站 120m / 意式冰淇淋/冰淇淋',
#   'price_lunch': '- JPY 999',
#   'price_dinner': '- JPY 999',
#   'holiday': '星期四'},
#  {'rating': '3.84',
#   'name': '一幸庵',
#   'link': 'https://tabelog.com/tw/tokyo/A1323/A132302/13005076/',
#   'area_genre': '茗荷谷車站 207m / 日式點心',
#   'price_lunch': '- JPY 999',
#   'price_dinner': '-',
#   'holiday': '星期一, 星期二, 星期日'},
#  {'rating': '3.84',
#   'name': 'Creperie Tirol',
#   'link': 'https://tabelog.com/tw/tokyo/A1318/A131814/13205650/',
#   'area_genre': '祖師谷大藏車站 271m / 可麗餅/法式薄餅',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': '-',
#   'holiday': '星期一, 星期四'},
#  {'rating': '3.84',
#   'name': 'LESS by Gabriele Riva & Kanako Sakakura',
#   'link': 'https://tabelog.com/tw/tokyo/A1303/A130302/13274859/',
#   'area_genre': '惠比壽車站 521m / 蛋糕, 巧克力',
#   'price_lunch': 'JPY 2,000 - JPY 2,999',
#   'price_dinner': '-',
#   'holiday': '星期三'},
#  {'rating': '3.83',
#   'name': 'VIRON 澀谷店',
#   'link': 'https://tabelog.com/tw/tokyo/A1303/A130301/13004626/',
#   'area_genre': '澀谷車站 465m / 麵包, 三明治, 蛋糕',
#   'price_lunch': '- JPY 999',
#   'price_dinner': '- JPY 999',
#   'holiday': '-'},
#  {'rating': '3.83',
#   'name': 'PATISSERIE ASAKO IWAYANAGI',
#   'link': 'https://tabelog.com/tw/tokyo/A1317/A131715/13189509/',
#   'area_genre': '等等力車站 232m / 蛋糕, 咖啡店',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 1,000 - JPY 1,999',
#   'holiday': '星期一, 星期二'},
#  {'rating': '3.83',
#   'name': '和光Tea Salon',
#   'link': 'https://tabelog.com/tw/tokyo/A1301/A130101/13009081/',
#   'area_genre': '銀座車站 53m / 咖啡店, 蛋糕',
#   'price_lunch': 'JPY 4,000 - JPY 4,999',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '-'},
#  {'rating': '3.83',
#   'name': 'Patisserie Yu Sasage',
#   'link': 'https://tabelog.com/tw/tokyo/A1318/A131809/13155662/',
#   'area_genre': '千歲烏山車站 273m / 蛋糕, 麵包',
#   'price_lunch': '- JPY 999',
#   'price_dinner': '-',
#   'holiday': '星期二, 星期三'},
#  {'rating': '3.83',
#   'name': 'Shizuka西式點心店 自然點心研究所 銀座5丁目店',
#   'link': 'https://tabelog.com/tw/tokyo/A1301/A130101/13270326/',
#   'area_genre': '銀座車站 122m / 西式甜點',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 1,000 - JPY 1,999',
#   'holiday': '-'},
#  {'rating': '3.82',
#   'name': "Nata de Cristiano's",
#   'link': 'https://tabelog.com/tw/tokyo/A1318/A131810/13153384/',
#   'area_genre': '代代木公園車站 185m / 甜食, 麵包, 蛋糕',
#   'price_lunch': '- JPY 999',
#   'price_dinner': '- JPY 999',
#   'holiday': '-'},
#  {'rating': '3.82',
#   'name': 'Patisserie TRES CALME',
#   'link': 'https://tabelog.com/tw/tokyo/A1323/A132301/13175122/',
#   'area_genre': '千石車站 235m / 蛋糕, 馬卡龍, 麵包',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': '-',
#   'holiday': '星期一'}]
